# %%
# !pip install dython

# %%
import pandas as pd

# %%
crashes = pd.read_csv('./crashes_cleaned.csv')
people = pd.read_csv('./people_cleaned.csv')
vehicles = pd.read_csv('./vehicles_cleaned.csv')
# Out:
# C:\Users\default.DESKTOP-SQ5PJUF\AppData\Local\Temp\ipykernel_25672\881923791.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   people = pd.read_csv('./people_cleaned.csv')

# %%
crashes.head()
# Out:
#    Unnamed: 0                                    CRASH_RECORD_ID  \
# 0           2  5f54a59fcb087b12ae5b1acff96a3caf4f2d37e79f8db4...
# 1          18  fd05285e9d273fe20cbbebf84794045828a2ba589073b6...
# 2          19  fda2491d33ac819033f4aaa7ed901120f2f6785b7e5bbb...
# 3          27  4a1f7a24129e5e1d4a7a2fd44ab6f8822a20bcdb2f627f...
# 4          28  1ee2180a89cc02c0b756f95b5b2755bb5cc9d93450f5ca...
#
#   CRASH_DATE_EST_I           CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0          UNKNOWN  2023-07-29 14:45:00                  30
# 1          UNKNOWN  2023-07-29 14:30:00                  10
# 2          UNKNOWN  2023-07-29 00:50:00                  30
# 3          UNKNOWN  2023-08-13 10:10:00                  30
# 4          UNKNOWN  2023-08-09 19:55:00                  30
#
#   TRAFFIC_CONTROL_DEVICE        DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL    FUNCTIONING PROPERLY             CLEAR
# 1            NO CONTROLS             NO CONTROLS           UNKNOWN
# ...

# %%
people.head()
# Out:
#   PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0   O749947      DRIVER  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# 1   O871921      DRIVER  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...
# 2   O848601      DRIVER  f25f09798b51603bde602ded37fea826fc8b7f962fc3b0...
# 3   O877654      DRIVER  e9146986f4b0884d00ff3a54da5249263b4b36c15d01ce...
# 4   O879085      DRIVER  f15ccbd94a8e29ce8424882ce93061d4e1d0deb214acfe...
#
#   VEHICLE_ID           CRASH_DATE  SEAT_NO           CITY    STATE ZIPCODE  \
# 0   834816.0  2019-09-28 03:30:00      0.0        CHICAGO       IL   60651
# 1   827212.0  2020-04-13 22:50:00      0.0        CHICAGO       IL   60620
# 2   805348.0  2020-02-23 18:15:00      0.0        CHICAGO       IL   60625
# 3   832624.0  2020-04-30 15:05:00      0.0        CHICAGO       IL   60620
# 4   833984.0  2020-05-03 22:30:00      0.0  CALUMENT CITY  Unknown   00000
#
# ...

# %%
vehicles.head()
# Out:
#    CRASH_UNIT_ID                                    CRASH_RECORD_ID  \
# 0        1717556  7b1763088507f77e0e552c009a6bf89a4d6330c7527706...
# 1        1717574  2603ff5a88f0b9b54576934c5ed4e4a64e8278e005687b...
# 2        1717579  a52ef70e33d468b855b5be44e8638a564434dcf99c0edf...
# 3        1720118  609055f4b1a72a44d6ec40ba9036cefd7c1287a755eb6c...
# 4        1720119  609055f4b1a72a44d6ec40ba9036cefd7c1287a755eb6c...
#
#                CRASH_DATE  UNIT_NO UNIT_TYPE  VEHICLE_ID      MAKE    MODEL  \
# 0  12/06/2023 03:24:00 PM        1    DRIVER   1634931.0    NISSAN   SENTRA
# 1  12/06/2023 04:00:00 PM        2    DRIVER   1634978.0  CHRYSLER  SEBRING
# 2  12/06/2023 04:30:00 PM        1    DRIVER   1634948.0    SUBARU  OUTBACK
# 3  12/10/2023 12:12:00 PM        1    DRIVER   1637401.0    TOYOTA     RAV4
# 4  12/10/2023 12:12:00 PM        2    DRIVER   1637408.0    SUBARU  OUTBACK
#
#   LIC_PLATE_STATE  VEHICLE_YEAR VEHICLE_DEFECT VEHICLE_TYPE VEHICLE_USE  \
# ...

# %%
data = crashes.merge(people, on='CRASH_RECORD_ID', how='inner').merge(vehicles, on='CRASH_RECORD_ID', how='inner')

# %%
data.head()

# %%
data.columns

# %%
data['INJURY_CLASSIFICATION'].value_counts()

# %%
column_list = [
    'POSTED_SPEED_LIMIT',
    'TRAFFIC_CONTROL_DEVICE',
    'DEVICE_CONDITON',
    'WEATHER_CONDITION',
    'LIGHTING_CONDITION',
    'FIRST_CRASH_TYPE',
    'TRAFFICWAY_TYPE',
    'LANE_CNT',
    'ALIGNMENT',
    'CRASH_TYPE',
    'INTERSECTION_RELATED_I',
    'NOT_RIGHT_OF_WAY_I',
    'HIT_AND_RUN_I',
    'DAMAGE',
    'PRIM_CONTRIBUTORY_CAUSE',
    'STREET_DIRECTION',
    'BEAT_OF_OCCURRENCE',
    'MOST_SEVERE_INJURY',
    'CRASH_HOUR',
    'CRASH_DAY_OF_WEEK',
    'CRASH_MONTH_x',
    'PERSON_TYPE',
    'CITY',
    'STATE',
    'ZIPCODE',
    'SEX',
    'AGE',
    'DRIVER_ACTION',
    'DRIVER_VISION',
    'MAKE',
    'MODEL',
    'LIC_PLATE_STATE',
    'VEHICLE YEAR',
    'VEHICLE_DEFECT',
    'VEHICLE_TYPE',
    'VEHICLE_USE',
    'TRAVEL_DIRECTION',
    'OCCUPANT_CNT'    
]

# %%
subset = data[column_list]

# %%
subset.head()

# %%
from dython.nominal import associations
associations(subset, figsize=(20, 20))
